# %% [markdown]
# # Fundamentos de Programação e Python
#
# ## 1.1 O que um Engenheiro de Agentes de IA precisa saber em Python?
#
# - Você já sentiu que seu código Python está ficando muito longo só para criar uma lista simples?
# - Hoje vamos aprender a reduzir 3 ou 4 linhas de código em apenas uma usando List Comprehension
# - **O que é List Comprehension?** _É uma forma rápida e direta de construir listas no Python._
# - Se você é **iniciante**, seu foco é aprender a ler o código de outras pessoas.
# - Se você é **intermediário**, seu foco é aprender a escrever de forma mais "pythônica" e eficiente.
#
# ## Explicação Geral sobre List comprehension
# -  List comprehension é uma sintaxe compacta e elegante do Python que permite criar novas listas aplicando uma expressão a cada elemento de um iterável (por exemplo, uma lista).
#
# -  **Por que usar?**
#     - O código fica mais limpo e legível, reduzindo múltiplas linhas a uma expressão concisa;
#     - Melhora a performance do script porque é mais rápido que loops tradicionais;
#     - Menos propenso a erros porque elimina necessidade de inicializar listas vazias e chamar .append();
#     - Estilo pythônico, isto é, segue as convenções da linguagem (PEP 20 - "The Zen of Python")
#
# ### Exemplo Genérico
# ```python
# nova_lista = [expressão for item in iterável if condição]
# ```
# - `expressão`: operação a ser aplicada em cada item
# - `item`: variável que representa cada elemento
# - `iterável`: sequência de dados a ser processada
# - `if condição`: filtro opcional
#
# # Caso de Uso 1: Transformação Simples (O Dobro dos Preços)
#   - **Problema:** Imagine uma lista de preços de uma loja e você precisa dobrar todos os valores.
#   - **Abordagem Tradicional:** usar um **Loop For**
#   - **Abordagem Profissional:** usar **List Comprehension:**
#
#
#
# 1. Quando NÃO usar List Comprehension [13:51]
#
#     Complexidade: Se a lógica envolver muitos if/else ou múltiplas linhas, o List Comprehension pode tornar o código difícil de ler.
#
#     Filosofia Python: "Simples é melhor que complexo". Se ficar confuso, volte para o for tradicional. O objetivo é clareza, não apenas redução de linhas. [14:15]
#
# 2. Conclusão e Call to Action [14:55]
#
#     Resumo: List Comprehension economiza tempo e deixa o código mais limpo.
#
#     Dica final: "Tente transformar seus loops for antigos em List Comprehension como exercício."
#
#     CTA: Pedir para curtir, se inscrever e comentar se conseguiram compreender a lógica.

# %% [markdown]
# # Caso de Uso 1: Transformação Simples (O Dobro dos Preços)
#   - **Problema:** Imagine uma lista de preços de uma loja e você precisa dobrar todos os valores.
#   - **Abordagem Tradicional:** usar um **Loop For**
#   - **Abordagem Profissional:** usar **List Comprehension:**

# %%
# ========================================
# Caso 1: Lista de Preços
# Problema: Dobrar todos os valores 
# ========================================

# Lista de preços de produtos
lista_precos = [10, 20, 30, 40, 50]

# ========================================
# Abordagem Tradicional: Loop For
# ========================================
lista_preco_dobrado1 = []
for preco in lista_precos:
    lista_preco_dobrado1.append(preco * 2)
print(lista_preco_dobrado1)

# ========================================
# Abordagem Profissional: List Comprehension
# ========================================
lista_preco_dobrado2 = [preco * 2 for preco in lista_precos]
print(lista_preco_dobrado2)
# Out:
# [20, 40, 60, 80, 100]
# [20, 40, 60, 80, 100]

# %% [markdown]
# # Caso de Uso 2: Filtragem com Condicional (IF)
#   - **Problema:** Calcular o imposto de importação (50%), mas apenas para produtos que custam mais de $1.000_
#   - **Abordagem Tradicional:** usar um **Loop For**
#   - **Abordagem Profissional:** usar **List Comprehension:**

# %%
# ========================================
# Caso 2: Filtragem com Condicional (IF)
# Problema: Calcular imposto de importação (50%) apenas para produtos > $1.000
# ========================================

# Lista de preços de produtos importados
precos_produtos = [500, 1200, 800, 2500, 1500, 300, 1100]

# ========================================
# Abordagem Tradicional: Loop For
# ========================================
impostos1 = []
for preco in precos_produtos:
    if preco > 1000:  # Apenas produtos acima de $1.000
        imposto = preco * 0.50  # Calcula 50% de imposto
        impostos1.append(imposto)

print("Impostos (Loop For):", impostos1)


# ========================================
# Abordagem Profissional: List Comprehension
# ========================================
# Serve para filtrar e transformar dados em uma única linha elegante
impostos2 = [preco * 0.50 for preco in precos_produtos if preco > 1000]

print("Impostos (List Comprehension):", impostos2)


# ========================================
# Comparação dos Resultados
# ========================================
print("\nProdutos originais:", precos_produtos)
print("Produtos taxados:", [p for p in precos_produtos if p > 1000])
print("Valores dos impostos:", impostos2)
# Out:
# Impostos (Loop For): [600.0, 1250.0, 750.0, 550.0]
# Impostos (List Comprehension): [600.0, 1250.0, 750.0, 550.0]
#
# Produtos originais: [500, 1200, 800, 2500, 1500, 300, 1100]
# Produtos taxados: [1200, 2500, 1500, 1100]
# Valores dos impostos: [600.0, 1250.0, 750.0, 550.0]

# %% [markdown]
# #### Aplicações de List Compreension no Universo de IA
#
# ##### 1. Pré-processamento de Dados
#
# - Normalização de valores:
# - Serve para escalar todos os valores entre 0 e 1, dividindo pelo valor máximo
# - Útil para preparar dados antes de treinar modelos de ML que são sensíveis à escala
#
# `[x / max_val for x in dados]`
#
# - Limpeza de texto:
#
# - Serve para padronizar textos: converter para minúsculas e remover espaços em branco nas pontas
# - Essencial no processamento de linguagem natural (NLP) para garantir consistência
#
# `[texto.lower().strip() for texto in documentos]`
#
# - Conversão de tipos:
#
# - Serve para converter strings numéricas em valores float (ponto flutuante)
# - Necessário quando dados vêm de CSVs, APIs ou inputs do usuário em formato texto
#
# `[float(x) for x in valores_string]`
#
# ##### 2. Feature Engineering
#
# -Criação de features:
#
# - Serve para criar uma nova feature baseada no comprimento dos textos
# - Útil em NLP para capturar a dimensão/verbosidade de documentos como característica
#
# `[len(texto) for texto in corpus]`
#
# -Transformações matemáticas:
#
# - Serve para aplicar transformação logarítmica, reduzindo efeito de outliers
# - O +1 evita log(0); comum em normalização de dados com distribuição assimétrica
#
# `[np.log(x + 1) for x in dados]`
#
# -One-hot encoding manual:
#
# - Serve para converter categoria em valor binário (1 se for 'A', 0 caso contrário)
# - Transforma variáveis categóricas em numéricas para modelos de ML
#
# `[1 if categoria == 'A' else 0 for categoria in categorias]`
#
# ##### 3. Processamento em Batch
#
# - Tokenização de textos:
# - Serve para dividir cada documento em tokens (palavras/subpalavras)
# - Essencial para preparar textos antes de alimentar modelos de linguagem
#
# `[tokenizar(doc) for doc in documentos]`
#
# - Extração de embeddings:
# - Serve para converter cada frase em um vetor numérico (embedding)
# - Permite que modelos de ML processem texto como representações vetoriais densas
#
# `[model.encode(texto) for texto in frases]`
#
# - Predições em lote:
# - Serve para fazer predições de múltiplas amostras de uma vez
# - Mais eficiente do que prever uma por vez, aproveitando paralelização
#
# `[modelo.predict(x) for x in batch]`
#
# ##### 4. Manipulação de Datasets
#
# - Filtrar dados:
# - Serve para selecionar apenas exemplos com label 1 (classe positiva)
# - Útil para criar subconjuntos balanceados ou analisar classes específicas
#
# `[x for x in dataset if x['label'] == 1]`
#
# - Extrair colunas específicas:
# - Serve para extrair apenas a coluna 'feature' de cada registro
# - Útil para isolar variáveis específicas de dicionários/objetos complexos
#
# `[registro['feature'] for registro in dados]`
#
# - Criar pares de treino:
# - Serve para combinar features com seus respectivos labels em tuplas (X, y)
# - Formato comum esperado por algoritmos de aprendizado supervisionado
#
# `[(x, y) for x, y in zip(features, labels)]`

# %%
# Exemplo de uso em sistemas de IA
# Preparar dados de texto para um modelo de classificação
textos_processados = [texto.lower().strip() for texto in textos_brutos if len(texto) > 10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Exemplo de uso em sistemas de IA
#       2 # Preparar dados de texto para um modelo de classificação
# ----> 3 textos_processados = [texto.lower().strip() for texto in textos_brutos if len(texto) > 10]
#
# NameError: name 'textos_brutos' is not defined

# %% [markdown]
# # Dicionários
# - A base para tudo em agentes
#
# ## O que é um Dicionário?
#
# - Diferente das listas, em que os itens são acessados pela posição (índice 0, 1, 2...), nos **dicionários** são utilizados **rótulos** chamados de **Chaves**.
#
# - A vantagem de usar dicionários é que são muito mais intuitivos. Em vez de decorar que o e-mail do gerente está na "posição 3", você simplesmente pede o e-mail da "Loja Leblon".
#
# - A **Estrutura** de um dicionário é composta por **pares de Chave: Valor**, sempre entre chaves {}.

# %%
# Dicionário Genérico
agente = {
    "nome": "Assistente",
    "função": "analisar",
    "ferramentas": ["pesquisar", "calcular"]
}

print(agente)
print(agente["nome"])
print(agente["função"])
print(agente["ferramentas"])

# %% [markdown]
# ## Acessando itens no dicionário
#
# - Para acessar itens no dicionário, usamos colchetes.

# %%
precos = {
    "iPad": 1000,
    "iPhone": 2000,
    "Notebook": 5000
    }

# Pegando o preço do iPhone
valor_iphone = precos["iPhone"]
print(valor_iphone)

# %% [markdown]
# ## Adicionar ou Modificar Itens do Dicionário
#
# - Para adicionar ou modificar itens no dicionário, usamos colchetes.
# - **Adicionar**: Se a chave não existe, o Python a cria.
# - **Modificar**: Se a chave já existe, o Python substitui o valor.

# %%
# Adicionando um novo produto
precos["Airpod"] = 500

# Modificando o preço do iPad
precos["iPad"] = 1200

print(precos)

# %% [markdown]
# ## Navegando no Dicionário (Loops)
#
# - Ao usar um Loop For no dicionário, o Python percorre as Chaves:

# %%
for produto in precos:
    print(produto)  # Vai printar iPad, iPhone, Notebook...

# %%
for produto in precos:
    print(f"O produto {produto} custa {precos[produto]}")

# %% [markdown]
# ## Métodos Importantes
#
# `.keys()` Retorna todas as chaves do dicionário
#
# `.values()` Retorna todos os valores.
#
# `.pop(chave)` Remove um item específico pela chave
#
# `.update(outro_dicionario)` Atualiza o dicionário com chaves e valores de outro dicionário

# %%
print(precos.keys())

print(precos.values())

print(precos.items())

precos.pop("iPad") # Remove o item

print(precos)

# %% [markdown]
# ## Verificar se um item existe
#
# - Antes de tentar acessar ou deletar, é boa prática verificar se a chave está lá:

# %%
if "iPad" in precos:
    print("O iPad está no catálogo")
else:
    print("Produto não encontrado")

# %% [markdown]
# #### Aplicações de Dicionários no Universo de IA
#
# ##### Configuração de Modelos e Hiperparâmetros
#
# - Dicionários são utilizados na Configuração de parâmetros do modelo;
# - Serve para armazenar todos os hiperparâmetros de um modelo em uma estrutura organizada;
# - Facilita o compartilhamento de configurações e reprodução de experimentos;
#
# `config = {'learning_rate': 0.001, 'epochs': 100, 'batch_size': 32}`
#
# ##### Configuração de agentes
#
# - Dicionários são usados para definir as características e ferramentas disponíveis para um agente de IA;
# - Dicionários permitem configuração flexível de diferentes tipos de agentes no mesmo sistema;
#
# `agente = {'nome': 'Assistente', 'função': 'analisar', 'ferramentas': ['pesquisar', 'calcular']}`
#
# ##### Salvar checkpoints de treinamento
#
# - Dicionários são usados para armazenar o estado completo do treinamento (época, loss, acurácia, pesos);
# - Dicionários permitem retomar treinamento do ponto exato em caso de interrupção;
#
# `checkpoint = {'epoch': 50, 'loss': 0.23, 'accuracy': 0.89, 'model_state': weights}`
#
# ##### Mapeamento de Classes e Labels
#
# - Dicionários são essenciais para tarefas de classificação onde o modelo trabalha com valores numéricos, por exemplo, para converter classes categóricas em números que o modelo possa processar;
#
# `label_map = {'gato': 0, 'cachorro': 1, 'pássaro': 2}`
#
# ##### Decodificação de predições:
#
# - Dicionários são usados para converter a saída numérica do modelo de volta para nomes legíveis, ou seja, converter números em classes categóricas que sejam compreensíveis ao usuário;
#
# `reverse_map = {0: 'negativo', 1: 'neutro', 2: 'positivo'}`
#
# ##### Mapeamento hierárquico de classes:
#
# - Dicionários são usados para organizar classes em categorias e subcategorias, assim como em classificação hierárquica ou quando há relacionamento entre classes;
#
# `categorias = {'animal': ['gato', 'cachorro'], 'objeto': ['cadeira', 'mesa']}`
#
# ##### Armazenamento de Métricas e Resultados
#
# - Dicionários são usados para armazenar todas as métricas de performance do modelo, assim como, permite comparar diferentes modelos e versões de forma organizada;
#
# `metricas = {'accuracy': 0.95, 'precision': 0.92, 'recall': 0.89, 'f1_score': 0.90}`
#
# ##### Histórico de treinamento:
#
# - Dicionários são usados para acompanhar a evolução das métricas em cada época e são úteis para visualizar curvas de aprendizado e detectar overfitting
#
# `historico = {'epoch_1': {'loss': 0.5, 'acc': 0.7}, 'epoch_2': {'loss': 0.3, 'acc': 0.85}}`
#
# ##### Resultados de validação cruzada:
#
# - Dicionários são usados para armazenar métricas de cada fold da validação cruzada, além de permitir calcular média e desvio padrão para avaliar estabilidade do modelo
#
# `cv_results = {'fold_1': 0.92, 'fold_2': 0.89, 'fold_3': 0.91, 'fold_4': 0.93, 'fold_5': 0.90}`
#
# ##### Cache e Otimização
#
# - Dicionários são usados para armazenar embeddings já calculados evitando recomputação, o que melhora drasticamente a performance em consultas repetidas
#
# `embedding_cache = {'texto1': [0.2, 0.5, 0.8], 'texto2': [0.1, 0.3, 0.9]}`
#
# ##### Cache de predições:
#
# - Dicionários são usados para guardar predições anteriores e retornar imediatamente se a mesma entrada aparecer, reduzindo a latência e custos computacionais em sistemas de produção;
#
# `pred_cache = {hash('input_data'): {'classe': 'positivo', 'confianca': 0.95}}`
#
# ##### Memorização de funções:
#
# - Dicionários são usados para armazenar resultados de funções custosas com base nos parâmetros de entrada, evitando recálculos desnecessários em operações determinísticas
#
# `memo = {(param1, param2): resultado_calculado}`
#
# ### Vocabulários e Tokenização
#
# - Dicionários são usados para Mapeamento token-para-índice:, isto é, servem para converter palavras em índices numéricos que o modelo processa;
# - Dicionários são uma base fundamental para modelos de NLP que trabalham com embeddings de palavras;
#
# `vocab = {'o': 0, 'a': 1, 'de': 2, 'que': 3, 'e': 4}`
#
# ##### Frequência de palavras:
# - Dicionários são usados para contar quantas vezes cada palavra aparece no corpus;
# - São úteis para criar vocabulários, remover stopwords ou calcular TF-IDF;
#
# `frequencias = {'python': 120, 'machine': 95, 'learning': 98, 'data': 150}`
#
# ##### Codificação especial de tokens:
#
# - Dicionários são usados para atribuir índices especiais a tokens de controle (padding, unknown, etc.)
# - Necessário para processar sequências de tamanhos variados em modelos de linguagem
#
# `tokens_especiais = {'<PAD>': 0, '<UNK>': 1, '<SOS>': 2, '<EOS>': 3}`
#
# ##### Estruturação de Datasets e Exemplos
#
# - Dicionários são utilizados na representação de exemplos de treino;
# - Servem para organizar cada exemplo com suas features e label de forma clara;
# - Facilitam o acesso a dados específicos e manutenção do código
#
# `exemplo = {'features': [1.2, 3.4, 5.6], 'label': 'positivo', 'id': 'sample_001'}`
#
# ##### Anotações de dados
#
# - Dicionários servem para armazenar metadados e anotações humanas sobre os dados e são essenciais em tarefas supervisionadas e projetos de anotação de dados
#
# `anotacao = {'texto': 'Este filme é ótimo', 'sentimento': 'positivo', 'anotador': 'João', 'confianca': 'alta'}`
#
# ##### Estruturar resposta de API
#
# - Dicionários são usados no retorno de predições de modelo via API de forma estruturada;
# - São um padrão comum em sistemas de ML em produção (MLOps)
#
# `resposta = {'predicao': 'spam', 'probabilidade': 0.87, 'tempo_processamento': 0.05, 'versao_modelo': 'v2.1'}`

# %% [markdown]
# ## Funções básicas
#
# - Se o ***List Comprehension*** encurta o código e o ***Dicionário*** organiza os dados, a ***Função*** é o que permite automatizar tarefas no seu script.
#
# - Em Python, uma função é um bloco de código que é executado quando é chamado. Lembre das Funções como um gabarito, isto é, você faz uma vez e usa quantas vezes quiser.
#
# - A sintaxe de uma função é a seguinte:
# ```python
# def nome_da_funcao(parametros):
#     # código da função
#     return resultado
# ```

# %% [markdown]
# ### 1. A Estrutura de uma Função
#
# - Para criar uma função, usamos a palavra reservada `def` (de *define*).
#
# - **`def`**: Avisa ao Python que estamos definindo uma função.
# - **Nome da função**: Escolha nomes que indiquem ação (ex: `dar_boas_vindas`).
# - **Parâmetros**: São as informações que a função precisa para trabalhar (ficam entre parênteses).
# - **Corpo**: Onde a mágica acontece (precisa estar indentado!).
# - **`return`**: O resultado que a função devolve para você.

# %%
def dar_boas_vindas(nome):
    print(f"Olá, {nome}! Seja bem-vindo à aula de Python.")

# Chamando a função
dar_boas_vindas("Pedro")

# %% [markdown]
# ### 2. Parâmetros e Argumentos
#
# - As funções podem receber dados para serem dinâmicas.
# - Imagine uma função que calcula o dobro de um número, por exemplo, os preços de um produto que falamos anteriormente neste Notebook.
# ---

# %%
precos_carros = [10000, 15000, 20000, 25000, 30000]

def calcular_dobro(valor):
    resultado = valor * 2
    return resultado

# Usando a função
precos_carros_novo = calcular_dobro(precos_carros[0])
print(precos_carros_novo) # Saída: 100

# %% [markdown]
# ### 3. Por que usar Funções? (As 3 Vantagens)
#
# 1. **Reutilização:** Se você precisa calcular um imposto em 10 partes diferentes do programa, você não escreve o cálculo 10 vezes. Você cria a função e a chama 10 vezes.
# 2. **Organização:** O código fica muito mais limpo. Em vez de um "textão" de código, você tem blocos nomeados.
# 3. **Manutenção:** Se a regra do imposto mudar, você altera em **um só lugar** (dentro da função) e todo o seu programa se atualiza automaticamente.
#
# ---
#
# ##### Importante:
#
# Toda vez que você se pegar dando **Ctrl+C / Ctrl+V** em um pedaço de código, pare tudo. Isso é um sinal claro de que aquele código deveria ser uma **Função**.

# %% [markdown]
# ## 4. Exemplo de Aplicação: Funções + Dicionários + List Comprehension
#
# - Criar uma função que recebe um dicionário de produtos e aplica um desconto usando List Comprehension:
# ---

# %%
# Dicionário de preços
precos_prod_tec = {"iPad": 5000, "iPhone": 8000, "Watch": 3000}

# Função para aplicar desconto
def aplicar_desconto(dicionario_precos, taxa):
    # Criando uma nova lista de preços com desconto
    return [valor * (1 - taxa) for valor in dicionario_precos.values() if valor > 3000]

# Aplicando 10% de desconto
precos_com_desconto = aplicar_desconto(precos_prod_tec, 0.10)
print(precos_com_desconto)

# %% [markdown]
# 🎯 Exercício Prático: Sistema de Gerenciamento de Agentes de IA
#
# - Você foi contratado para criar um sistema simples que gerencia múltiplos agentes de IA.
# - Cada agente tem um nome, uma função, uma lista de ferramentas e um nível de confiança (score entre 0 e 1).

# %%
# Lista de agentes (cada um é um dicionário)
agentes = [
    {'nome': 'Assistente', 'funcao': 'atendimento', 'ferramentas': ['chat', 'email'], 'confianca': 0.95},
    {'nome': 'Analista', 'funcao': 'analise', 'ferramentas': ['sql', 'python', 'excel'], 'confianca': 0.88},
    {'nome': 'Pesquisador', 'funcao': 'pesquisa', 'ferramentas': ['web', 'papers'], 'confianca': 0.92},
    {'nome': 'Tradutor', 'funcao': 'traducao', 'ferramentas': ['tradutor', 'dicionario'], 'confianca': 0.78},
    {'nome': 'Programador', 'funcao': 'programacao', 'ferramentas': ['python', 'javascript', 'git'], 'confianca': 0.85},
]

# %% [markdown]
# ✅ Questão 1: Filtrar agentes confiáveis (List Comprehension)
# Tarefa: Crie uma lista apenas com os nomes dos agentes que têm confiança maior ou igual a 0.85

# %%
# Lista de agentes (cada um é um dicionário)
agentes = [
    {'nome': 'Assistente', 'funcao': 'atendimento', 'ferramentas': ['chat', 'email'], 'confianca': 0.95},
    {'nome': 'Analista', 'funcao': 'analise', 'ferramentas': ['sql', 'python', 'excel'], 'confianca': 0.88},
    {'nome': 'Pesquisador', 'funcao': 'pesquisa', 'ferramentas': ['web', 'papers'], 'confianca': 0.92},
    {'nome': 'Tradutor', 'funcao': 'traducao', 'ferramentas': ['tradutor', 'dicionario'], 'confianca': 0.78},
    {'nome': 'Programador', 'funcao': 'programacao', 'ferramentas': ['python', 'javascript', 'git'], 'confianca': 0.85},
]


# Lista com o nome dos Agentes de IA confiáveis utilizando Loop For
agentes_confiaveis1 = []

for agente in agentes:
    if agente['confianca'] >=0.85:
        agentes_confiaveis1.append(agente['nome'])

print(agentes_confiaveis1)
# Resultado esperado: ['Assistente', 'Analista', 'Pesquisador', 'Programador']
# Out:
# ['Assistente', 'Analista', 'Pesquisador', 'Programador']

# %%
# Lista de agentes (cada um é um dicionário)
agentes = [
    {'nome': 'Assistente', 'funcao': 'atendimento', 'ferramentas': ['chat', 'email'], 'confianca': 0.95},
    {'nome': 'Analista', 'funcao': 'analise', 'ferramentas': ['sql', 'python', 'excel'], 'confianca': 0.88},
    {'nome': 'Pesquisador', 'funcao': 'pesquisa', 'ferramentas': ['web', 'papers'], 'confianca': 0.92},
    {'nome': 'Tradutor', 'funcao': 'traducao', 'ferramentas': ['tradutor', 'dicionario'], 'confianca': 0.78},
    {'nome': 'Programador', 'funcao': 'programacao', 'ferramentas': ['python', 'javascript', 'git'], 'confianca': 0.85},
]


# Lista com o nome dos Agentes de IA confiáveis utilizando Loop For
agentes_confiaveis2 = [agente['nome'] for agente in agentes if agente['confianca']>=0.85]

print(agentes_confiaveis2)
# Resultado esperado: ['Assistente', 'Analista', 'Pesquisador', 'Programador']
# Out:
# ['Assistente', 'Analista', 'Pesquisador', 'Programador']

# %% [markdown]
# ✅ Questão 2: Criar mapeamento de funções (Dicionário)
#
# **Tarefa:** Crie um dicionário que mapeia cada função para o nome do agente responsável

# %%
# Começar com dicionário vazio
mapa_funcoes1 = {}

# Para cada agente, adicionar: função → nome
for agente in agentes:
    mapa_funcoes1[agente['funcao']] = agente['nome']

print(mapa_funcoes1)

# Resultado esperado: {'atendimento': 'Assistente', 'analise': 'Analista', ...}
# Out:
# {'atendimento': 'Assistente', 'analise': 'Analista', 'pesquisa': 'Pesquisador', 'traducao': 'Tradutor', 'programacao': 'Programador'}

# %%
# Dictionarie Comprehension
mapa_funcoes2 = {agente['funcao']:agente['nome'] for agente in agentes}

print(mapa_funcoes2)
# Resultado esperado: {'atendimento': 'Assistente', 'analise': 'Analista', ...}
# Out:
# {'atendimento': 'Assistente', 'analise': 'Analista', 'pesquisa': 'Pesquisador', 'traducao': 'Tradutor', 'programacao': 'Programador'}

# %% [markdown]
# ✅ Questão 3: Função de busca (Função + Dicionário)
#
# **Tarefa:** Crie uma função chamada `buscar_agente_por_funcao(funcao)` que recebe o nome de uma função e retorna o agente completo (dicionário) responsável por ela.
#
# **Dica:** Use um dicionário para mapear função → agente completo

# %%
# Seu código aqui
def buscar_agente_por_funcao(funcao):
    mapa = {agente['funcao']: agente for agente in agentes}
    return mapa[funcao]

# Teste
resultado = buscar_agente_por_funcao('atendimento')
print(resultado)
# Resultado esperado: {'nome': 'Analista', 'funcao': 'analise', 'ferramentas': ['sql', 'python', 'excel'], 'confianca': 0.88}
# Out:
# {'nome': 'Assistente', 'funcao': 'atendimento', 'ferramentas': ['chat', 'email'], 'confianca': 0.95}

# %% [markdown]
# ✅ Questão 4: Função + List Comprehension + Dicionário (DESAFIO!)
#
# - **Tarefa:** Crie uma função criar_relatorio(min_confianca) que:
#
# 1. Filtra agentes com confiança `>= min_confianca`
# 2. Para cada agente filtrado, retorna um dicionário com:
# - `nome`
# - `num_ferramentas` (quantidade de ferramentas que ele possui)
# - `confianca`

# %%
# Seu código aqui
def criar_relatorio(min_confianca):
    return [{
        'nome':agente['nome'],
        'num_ferramentas':len(agente['ferramentas']),
        'confianca':agente['confianca']
    }]

# Teste
resultado = criar_relatorio(0.85)
print(resultado)
# Resultado esperado:
# [
#     {'nome': 'Assistente', 'num_ferramentas': 2, 'confianca': 0.95},
#     {'nome': 'Analista', 'num_ferramentas': 3, 'confianca': 0.88},
#     {'nome': 'Pesquisador', 'num_ferramentas': 2, 'confianca': 0.92},
#     {'nome': 'Programador', 'num_ferramentas': 3, 'confianca': 0.85}
# ]
# Out:
# [{'nome': 'Programador', 'num_ferramentas': 3, 'confianca': 0.85}]
